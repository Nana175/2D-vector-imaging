# %%
import pandas as pd

# %%
version = 0
logs_dir = f'../logs/tanh/version_{version}/'
csv_file =  logs_dir + 'metrics.csv'
df = pd.read_csv(csv_file)
df
# Out:
#      epoch  lr-Adam   step  test_loss   test_r2  train_loss_epoch  \
# 0      NaN   0.0001      0        NaN       NaN               NaN
# 1      0.0      NaN     49        NaN       NaN               NaN
# 2      0.0      NaN     99        NaN       NaN               NaN
# 3      0.0      NaN    149        NaN       NaN               NaN
# 4      0.0      NaN    199        NaN       NaN               NaN
# ..     ...      ...    ...        ...       ...               ...
# 466   32.0      NaN  18499        NaN       NaN               NaN
# 467   32.0      NaN  18549        NaN       NaN               NaN
# 468   32.0      NaN  18578        NaN       NaN               NaN
# 469   32.0      NaN  18578        NaN       NaN          0.000029
# 470   33.0      NaN  18579   0.001665  0.638653               NaN
#
#      train_loss_step  val_loss
# 0                NaN       NaN
# 1           0.002661       NaN
# 2           0.002413       NaN
# 3           0.001702       NaN
# ...

# %%
ax = df.groupby('epoch').min()[['train_loss_epoch', 'val_loss']].plot()
ax.set_title('Learning Curve For MSE')
# Out:
# Text(0.5, 1.0, 'Learning Curve For MSE')

# %%
df.groupby('epoch').min()[['train_loss_epoch', 'val_loss']].plot()
